# %% [markdown]
# # Computing temperature-dependent intrinsic parameters
#
# In this notebook we show how we can get temperature dependent Ms, A, and K by running spindynamics simulations for a range of temperatures and then fitting the Kuzmin equation to the resulting M(T). From the fit we can get A(T) and K(T).

# %%
import mammos_analysis
import matplotlib.pyplot as plt
from mammos_spindynamics import uppasd

# %% [markdown]
# ## Creating the simulation object
#
# First, we need to create a simulation object. We assume that we already have three files `posfile`, `momfile` and `jfile` in our current working directory and that they are in the form required for UppASD. We will not create `inpsd.dat` manually but instead rely on the simulation object. We can pass all required options for the input file as arguments when creating the simulation object or when calling one of its functions. Here, we will pass most arguments at creation time and only temperature values at runtime.
#
# We take CrNiP as an example for this notebook.

# %%
sim = uppasd.Simulation(
    cell=[(5.058, -2.92, 0.0), (0.0, 5.84, 0.0), (0.0, 0.0, 3.51)],
    ncell=[25, 25, 25],
    BC=["P", "P", "P"],
    alat=1.00e-10,
    Initmag=3,
    posfiletype="D",
    mode="M",
    momfile="uppasd_data/momfile",
    posfile="uppasd_data/posfile",
    exchange="uppasd_data/jfile",
    mcnstep=1000,
)

# %% [markdown]
# To see a list of all available arguments (a subset of what UppASD supports) and information whether they are required and their default value (if any), use:

# %%
uppasd.Simulation.defaults

# %% [raw]
# print("""\
# Argument    Required    Default
# simid       True        <will be set to output name with special characters converted to underscores>
# ncell       True        (25, 25, 25)
# BC          True        ("P", "P", "P")
# cell        True
# posfile     True        ./posfile
# posfiletype True        D
# momfile     True        ./momfile
# exchange    True        ./jfile
# anisotropy  False
# Sym         True        0
# Initmag     True
# restartfile False
# ip_mode     True        M
# ip_temp     True
# mcNstep     True        50000
# mode        True        M
# temp        True
# mcnstep     True        50000
# ...
# """)

# %% [markdown]
# ## Running a temperature sweep
#
# We now want to run simulations for a series of temperatures between 10 and 500 Kelvin, in steps of 50 Kelvin. We can use the `range` function to get all temperatures. The simulation object provides a method to automatically run all simulations sequentially. We can tell it to use the restart file of the previous calculation as starting point for the next simulation. For the first simulation it will use `Initmag=1`, which we have set above.

# %%
sim.temperature_sweep(
    T=range(10, 500, 50), restart_with_previous=True, out="CrNiP", description="Anything the user wants to record"
)
# Out:
#  --------------------------------------------------------------
#              __  __          ___   _______    ____  ___
#             / / / /__  ___  / _ | / __/ _ \  / __/ / _ \
#            / /_/ / _ \/ _ \/ __ |_\ \/ // / / _ \_/ // /
#            \____/ .__/ .__/_/ |_/___/____/  \___(_)___/
#                /_/  /_/
#  --------------------------------------------------------------
#                 https://github.com/UppASD/UppASD
#  --------------------------------------------------------------
#               Division of Materials Theory
#               Department of Physics and Astronomy
#               Uppsala University
#               Sweden
#  ---------------------Production-version-----------------------
#  Git revision: v6.0.2-136-g553a
#  --------------------------------------------------------------
#  RNG: Mersenne-Twister (mtprng)
#  --------------------------------------------------------------
#  Execution Date: 09/12/2025  Execution Time: 22:17:59:320
#  --------------------------------------------------------------
#  Using OpenMP with 16  threads out of 16 possible.
#  --------------------------------------------------------------
#  Read input file using new format
#  done.
#   Set up types of atoms done
#   Set up chemical information of alloy done
#   Set up global coordinates done
#   Set up damping
#   done
#   Set up temperature
#   done
#  Write input data done.
#  Set up Hamiltonian
#   Set up neighbour map for exchange nntype           0 -2147483648
#  done
#   Mount Heisenberg Hamiltonian done
#   Calculate mean-field estimate of Tc:  ** On entry to DGEEV  parameter number  5 had an illegal value
#   Problem in dgeev:  -5
#    -Inf K.
#   Max eigenvalue:********** meV
#  Initialize metatype
#  Initialize magnetic moments
#   Moments from inpsd.dat  done
#  Enter initial phase:  N
#  Enter measurement phase:
#   MP MC   5% done. Mbar:       NaN. U:     NaN.
#   MP MC  10% done. Mbar:       NaN. U:     NaN.
#   MP MC  15% done. Mbar:       NaN. U:     NaN.
#   MP MC  20% done. Mbar:       NaN. U:     NaN.
#   MP MC  25% done. Mbar:       NaN. U:     NaN.
#   MP MC  30% done. Mbar:       NaN. U:     NaN.
#   MP MC  35% done. Mbar:       NaN. U:     NaN.
#   MP MC  40% done. Mbar:       NaN. U:     NaN.
#   MP MC  45% done. Mbar:       NaN. U:     NaN.
#   MP MC  50% done. Mbar:       NaN. U:     NaN.
#   MP MC  55% done. Mbar:       NaN. U:     NaN.
#   MP MC  60% done. Mbar:       NaN. U:     NaN.
#   MP MC  65% done. Mbar:       NaN. U:     NaN.
#   MP MC  70% done. Mbar:       NaN. U:     NaN.
#   MP MC  75% done. Mbar:       NaN. U:     NaN.
#   MP MC  80% done. Mbar:       NaN. U:     NaN.
#   MP MC  85% done. Mbar:       NaN. U:     NaN.
#   MP MC  90% done. Mbar:       NaN. U:     NaN.
#   MP MC  95% done. Mbar:       NaN. U:     NaN.
#   MP MC 100% done. Mbar:       NaN. U:     NaN.
#  Simulation finished
#  ----------------TIME CONSUMPTION REPORT----------------------
#  CATEGORY                 TIME(sec)           PERCENT
#   Startup                  1.67E-02              31.3
#   Initial                  1.82E-03               3.4
#   Measurement              3.68E-03               6.9
#   MonteCarlo               1.76E-03               3.3
#   PrintRestart             1.81E-06               0.0
#   SpinCorr                 3.64E-03               6.8
#  -------------------------------------------------------------
#  Total wall time           5.35E-02      Sampled percent  51.6
#  --------------MAIN PROGRAM PHASES TIME REPORT----------------
#  CATEGORY                   EXECUTION TIME    TOTAL CPU TIME
#   Time for initialization :           0.04              0.57
#   Time for initial phase  :           0.00              0.03
#   Time for meas. phase    :           0.02              0.26
#   Time for cleanup        :           0.00              0.00
#  -------------------------------------------------------------
#   Time total              :           0.06              0.86
#   Time for one meas. iter :           0.02              0.26
#  -------------------MEMORY CONSUMPTION REPORT-----------------------
#  5 allocations and 5 deallocations, remaining memory(B):0
#  Memory occupation peak: 0 kB
#  For the array: "indxb_avrg" in routine "averages_allocations"
#  -----------------END MEMORY CONSUMPTION REPORT---------------------
#  --------------------------------------------------------------
#              __  __          ___   _______    ____  ___
#             / / / /__  ___  / _ | / __/ _ \  / __/ / _ \
#            / /_/ / _ \/ _ \/ __ |_\ \/ // / / _ \_/ // /
#            \____/ .__/ .__/_/ |_/___/____/  \___(_)___/
#                /_/  /_/
#  --------------------------------------------------------------
#                 https://github.com/UppASD/UppASD
#  --------------------------------------------------------------
#               Division of Materials Theory
#               Department of Physics and Astronomy
#               Uppsala University
#               Sweden
#  ---------------------Production-version-----------------------
#  Git revision: v6.0.2-136-g553a
#  --------------------------------------------------------------
#  RNG: Mersenne-Twister (mtprng)
#  --------------------------------------------------------------
#  Execution Date: 09/12/2025  Execution Time: 22:17:59:460
#  --------------------------------------------------------------
#  Using OpenMP with 16  threads out of 16 possible.
#  --------------------------------------------------------------
#  Read input file using new format
#  done.
#   Set up types of atoms done
#   Set up chemical information of alloy done
#   Set up global coordinates done
#   Set up damping
#   done
#   Set up temperature
#   done
#  Write input data done.
#  Set up Hamiltonian
#   Set up neighbour map for exchange nntype           0 -2147483648
#  done
#   Mount Heisenberg Hamiltonian done
#   Calculate mean-field estimate of Tc:  ** On entry to DGEEV  parameter number  5 had an illegal value
#   Problem in dgeev:  -5
#    -Inf K.
#   Max eigenvalue:********** meV
#  Initialize metatype
#  Initialize magnetic moments
#   Moments from inpsd.dat  done
#  Enter initial phase:  N
#  Enter measurement phase:
#   MP MC   5% done. Mbar:       NaN. U:     NaN.
#   MP MC  10% done. Mbar:       NaN. U:     NaN.
#   MP MC  15% done. Mbar:       NaN. U:     NaN.
#   MP MC  20% done. Mbar:       NaN. U:     NaN.
#   MP MC  25% done. Mbar:       NaN. U:     NaN.
#   MP MC  30% done. Mbar:       NaN. U:     NaN.
#   MP MC  35% done. Mbar:       NaN. U:     NaN.
#   MP MC  40% done. Mbar:       NaN. U:     NaN.
#   MP MC  45% done. Mbar:       NaN. U:     NaN.
#   MP MC  50% done. Mbar:       NaN. U:     NaN.
#   MP MC  55% done. Mbar:       NaN. U:     NaN.
#   MP MC  60% done. Mbar:       NaN. U:     NaN.
#   MP MC  65% done. Mbar:       NaN. U:     NaN.
#   MP MC  70% done. Mbar:       NaN. U:     NaN.
#   MP MC  75% done. Mbar:       NaN. U:     NaN.
#   MP MC  80% done. Mbar:       NaN. U:     NaN.
#   MP MC  85% done. Mbar:       NaN. U:     NaN.
#   MP MC  90% done. Mbar:       NaN. U:     NaN.
#   MP MC  95% done. Mbar:       NaN. U:     NaN.
#   MP MC 100% done. Mbar:       NaN. U:     NaN.
#  Simulation finished
#  ----------------TIME CONSUMPTION REPORT----------------------
#  CATEGORY                 TIME(sec)           PERCENT
#   Startup                  2.72E-02              41.9
#   Initial                  6.88E-07               0.0
#   Measurement              9.57E-04               1.5
#   MonteCarlo               7.43E-03              11.5
#   PrintRestart             1.81E-06               0.0
#   SpinCorr                 3.24E-04               0.5
#  -------------------------------------------------------------
#  Total wall time           6.48E-02      Sampled percent  55.4
#  --------------MAIN PROGRAM PHASES TIME REPORT----------------
#  CATEGORY                   EXECUTION TIME    TOTAL CPU TIME
#   Time for initialization :           0.05              0.58
#   Time for initial phase  :           0.00              0.01
#   Time for meas. phase    :           0.02              0.30
#   Time for cleanup        :           0.00              0.00
#  -------------------------------------------------------------
#   Time total              :           0.07              0.88
#   Time for one meas. iter :           0.02              0.30
#  -------------------MEMORY CONSUMPTION REPORT-----------------------
#  5 allocations and 5 deallocations, remaining memory(B):0
#  Memory occupation peak: 0 kB
#  For the array: "indxb_avrg" in routine "averages_allocations"
#  -----------------END MEMORY CONSUMPTION REPORT---------------------
#  --------------------------------------------------------------
#              __  __          ___   _______    ____  ___
#             / / / /__  ___  / _ | / __/ _ \  / __/ / _ \
#            / /_/ / _ \/ _ \/ __ |_\ \/ // / / _ \_/ // /
#            \____/ .__/ .__/_/ |_/___/____/  \___(_)___/
#                /_/  /_/
#  --------------------------------------------------------------
#                 https://github.com/UppASD/UppASD
#  --------------------------------------------------------------
#               Division of Materials Theory
#               Department of Physics and Astronomy
#               Uppsala University
#               Sweden
#  ---------------------Production-version-----------------------
#  Git revision: v6.0.2-136-g553a
#  --------------------------------------------------------------
#  RNG: Mersenne-Twister (mtprng)
#  --------------------------------------------------------------
#  Execution Date: 09/12/2025  Execution Time: 22:17:59:619
#  --------------------------------------------------------------
#  Using OpenMP with 16  threads out of 16 possible.
#  --------------------------------------------------------------
#  Read input file using new format
#  done.
#   Set up types of atoms done
#   Set up chemical information of alloy done
#   Set up global coordinates done
#   Set up damping
#   done
#   Set up temperature
#   done
#  Write input data done.
#  Set up Hamiltonian
#   Set up neighbour map for exchange nntype           0 -2147483648
#  done
#   Mount Heisenberg Hamiltonian done
#   Calculate mean-field estimate of Tc:  ** On entry to DGEEV  parameter number  5 had an illegal value
#   Problem in dgeev:  -5
#    -Inf K.
#   Max eigenvalue:********** meV
#  Initialize metatype
#  Initialize magnetic moments
#   Moments from inpsd.dat  done
#  Enter initial phase:  N
#  Enter measurement phase:
#   MP MC   5% done. Mbar:       NaN. U:     NaN.
#   MP MC  10% done. Mbar:       NaN. U:     NaN.
#   MP MC  15% done. Mbar:       NaN. U:     NaN.
#   MP MC  20% done. Mbar:       NaN. U:     NaN.
#   MP MC  25% done. Mbar:       NaN. U:     NaN.
#   MP MC  30% done. Mbar:       NaN. U:     NaN.
#   MP MC  35% done. Mbar:       NaN. U:     NaN.
#   MP MC  40% done. Mbar:       NaN. U:     NaN.
#   MP MC  45% done. Mbar:       NaN. U:     NaN.
#   MP MC  50% done. Mbar:       NaN. U:     NaN.
#   MP MC  55% done. Mbar:       NaN. U:     NaN.
#   MP MC  60% done. Mbar:       NaN. U:     NaN.
#   MP MC  65% done. Mbar:       NaN. U:     NaN.
#   MP MC  70% done. Mbar:       NaN. U:     NaN.
#   MP MC  75% done. Mbar:       NaN. U:     NaN.
#   MP MC  80% done. Mbar:       NaN. U:     NaN.
#   MP MC  85% done. Mbar:       NaN. U:     NaN.
#   MP MC  90% done. Mbar:       NaN. U:     NaN.
#   MP MC  95% done. Mbar:       NaN. U:     NaN.
#   MP MC 100% done. Mbar:       NaN. U:     NaN.
#  Simulation finished
#  ----------------TIME CONSUMPTION REPORT----------------------
#  CATEGORY                 TIME(sec)           PERCENT
#   Startup                  3.44E-02              35.4
#   Initial                  7.40E-03               7.6
#   Measurement              6.47E-03               6.7
#   MonteCarlo               1.22E-02              12.6
#   PrintRestart             1.87E-06               0.0
#   SpinCorr                 3.13E-03               3.2
#  -------------------------------------------------------------
#  Total wall time           9.72E-02      Sampled percent  65.5
#  --------------MAIN PROGRAM PHASES TIME REPORT----------------
#  CATEGORY                   EXECUTION TIME    TOTAL CPU TIME
#   Time for initialization :           0.05              0.67
#   Time for initial phase  :           0.02              0.23
#   Time for meas. phase    :           0.05              0.64
#   Time for cleanup        :           0.00              0.00
#  -------------------------------------------------------------
#   Time total              :           0.11              1.55
#   Time for one meas. iter :           0.05              0.64
#  -------------------MEMORY CONSUMPTION REPORT-----------------------
#  5 allocations and 5 deallocations, remaining memory(B):0
#  Memory occupation peak: 0 kB
#  For the array: "indxb_avrg" in routine "averages_allocations"
#  -----------------END MEMORY CONSUMPTION REPORT---------------------
#  --------------------------------------------------------------
#              __  __          ___   _______    ____  ___
#             / / / /__  ___  / _ | / __/ _ \  / __/ / _ \
#            / /_/ / _ \/ _ \/ __ |_\ \/ // / / _ \_/ // /
#            \____/ .__/ .__/_/ |_/___/____/  \___(_)___/
#                /_/  /_/
#  --------------------------------------------------------------
#                 https://github.com/UppASD/UppASD
#  --------------------------------------------------------------
#               Division of Materials Theory
#               Department of Physics and Astronomy
#               Uppsala University
#               Sweden
#  ---------------------Production-version-----------------------
#  Git revision: v6.0.2-136-g553a
#  --------------------------------------------------------------
#  RNG: Mersenne-Twister (mtprng)
#  --------------------------------------------------------------
#  Execution Date: 09/12/2025  Execution Time: 22:17:59:829
#  --------------------------------------------------------------
#  Using OpenMP with 16  threads out of 16 possible.
#  --------------------------------------------------------------
#  Read input file using new format
#  done.
#   Set up types of atoms done
#   Set up chemical information of alloy done
#   Set up global coordinates done
#   Set up damping
#   done
#   Set up temperature
#   done
#  Write input data done.
#  Set up Hamiltonian
#   Set up neighbour map for exchange nntype           0 -2147483648
#  done
#   Mount Heisenberg Hamiltonian done
#   Calculate mean-field estimate of Tc:  ** On entry to DGEEV  parameter number  5 had an illegal value
#   Problem in dgeev:  -5
#    -Inf K.
#   Max eigenvalue:********** meV
#  Initialize metatype
#  Initialize magnetic moments
#   Moments from inpsd.dat  done
#  Enter initial phase:  N
#  Enter measurement phase:
#   MP MC   5% done. Mbar:       NaN. U:     NaN.
#   MP MC  10% done. Mbar:       NaN. U:     NaN.
#   MP MC  15% done. Mbar:       NaN. U:     NaN.
#   MP MC  20% done. Mbar:       NaN. U:     NaN.
#   MP MC  25% done. Mbar:       NaN. U:     NaN.
#   MP MC  30% done. Mbar:       NaN. U:     NaN.
#   MP MC  35% done. Mbar:       NaN. U:     NaN.
#   MP MC  40% done. Mbar:       NaN. U:     NaN.
#   MP MC  45% done. Mbar:       NaN. U:     NaN.
#   MP MC  50% done. Mbar:       NaN. U:     NaN.
#   MP MC  55% done. Mbar:       NaN. U:     NaN.
#   MP MC  60% done. Mbar:       NaN. U:     NaN.
#   MP MC  65% done. Mbar:       NaN. U:     NaN.
#   MP MC  70% done. Mbar:       NaN. U:     NaN.
#   MP MC  75% done. Mbar:       NaN. U:     NaN.
#   MP MC  80% done. Mbar:       NaN. U:     NaN.
#   MP MC  85% done. Mbar:       NaN. U:     NaN.
#   MP MC  90% done. Mbar:       NaN. U:     NaN.
#   MP MC  95% done. Mbar:       NaN. U:     NaN.
#   MP MC 100% done. Mbar:       NaN. U:     NaN.
#  Simulation finished
#  ----------------TIME CONSUMPTION REPORT----------------------
#  CATEGORY                 TIME(sec)           PERCENT
#   Startup                  3.97E-03              20.8
#   Initial                  3.75E-07               0.0
#   Measurement              4.03E-03              21.1
#   MonteCarlo               1.02E-02              53.3
#   PrintRestart             1.81E-06               0.0
#   SpinCorr                 1.65E-04               0.9
#  -------------------------------------------------------------
#  Total wall time           1.91E-02      Sampled percent  96.0
#  --------------MAIN PROGRAM PHASES TIME REPORT----------------
#  CATEGORY                   EXECUTION TIME    TOTAL CPU TIME
#   Time for initialization :           0.00              0.06
#   Time for initial phase  :           0.00              0.00
#   Time for meas. phase    :           0.01              0.24
#   Time for cleanup        :           0.00              0.00
#  -------------------------------------------------------------
#   Time total              :           0.02              0.30
#   Time for one meas. iter :           0.01              0.24
#  -------------------MEMORY CONSUMPTION REPORT-----------------------
#  5 allocations and 5 deallocations, remaining memory(B):0
#  Memory occupation peak: 0 kB
#  For the array: "indxb_avrg" in routine "averages_allocations"
#  -----------------END MEMORY CONSUMPTION REPORT---------------------
#  --------------------------------------------------------------
#              __  __          ___   _______    ____  ___
#             / / / /__  ___  / _ | / __/ _ \  / __/ / _ \
#            / /_/ / _ \/ _ \/ __ |_\ \/ // / / _ \_/ // /
#            \____/ .__/ .__/_/ |_/___/____/  \___(_)___/
#                /_/  /_/
#  --------------------------------------------------------------
#                 https://github.com/UppASD/UppASD
#  --------------------------------------------------------------
#               Division of Materials Theory
#               Department of Physics and Astronomy
#               Uppsala University
#               Sweden
#  ---------------------Production-version-----------------------
#  Git revision: v6.0.2-136-g553a
#  --------------------------------------------------------------
#  RNG: Mersenne-Twister (mtprng)
#  --------------------------------------------------------------
#  Execution Date: 09/12/2025  Execution Time: 22:17:59:945
#  --------------------------------------------------------------
#  Using OpenMP with 16  threads out of 16 possible.
#  --------------------------------------------------------------
#  Read input file using new format
#  done.
#   Set up types of atoms done
#   Set up chemical information of alloy done
#   Set up global coordinates done
#   Set up damping
#   done
#   Set up temperature
#   done
#  Write input data done.
#  Set up Hamiltonian
#   Set up neighbour map for exchange nntype           0 -2147483648
#  done
#   Mount Heisenberg Hamiltonian done
#   Calculate mean-field estimate of Tc:  ** On entry to DGEEV  parameter number  5 had an illegal value
#   Problem in dgeev:  -5
#    -Inf K.
#   Max eigenvalue:********** meV
#  Initialize metatype
#  Initialize magnetic moments
#   Moments from inpsd.dat  done
#  Enter initial phase:  N
#  Enter measurement phase:
#   MP MC   5% done. Mbar:       NaN. U:     NaN.
#   MP MC  10% done. Mbar:       NaN. U:     NaN.
#   MP MC  15% done. Mbar:       NaN. U:     NaN.
#   MP MC  20% done. Mbar:       NaN. U:     NaN.
#   MP MC  25% done. Mbar:       NaN. U:     NaN.
#   MP MC  30% done. Mbar:       NaN. U:     NaN.
#   MP MC  35% done. Mbar:       NaN. U:     NaN.
#   MP MC  40% done. Mbar:       NaN. U:     NaN.
#   MP MC  45% done. Mbar:       NaN. U:     NaN.
#   MP MC  50% done. Mbar:       NaN. U:     NaN.
#   MP MC  55% done. Mbar:       NaN. U:     NaN.
#   MP MC  60% done. Mbar:       NaN. U:     NaN.
#   MP MC  65% done. Mbar:       NaN. U:     NaN.
#   MP MC  70% done. Mbar:       NaN. U:     NaN.
#   MP MC  75% done. Mbar:       NaN. U:     NaN.
#   MP MC  80% done. Mbar:       NaN. U:     NaN.
#   MP MC  85% done. Mbar:       NaN. U:     NaN.
#   MP MC  90% done. Mbar:       NaN. U:     NaN.
#   MP MC  95% done. Mbar:       NaN. U:     NaN.
#   MP MC 100% done. Mbar:       NaN. U:     NaN.
#  Simulation finished
#  ----------------TIME CONSUMPTION REPORT----------------------
#  CATEGORY                 TIME(sec)           PERCENT
#   Startup                  9.72E-03              33.1
#   Initial                  4.19E-06               0.0
#   Measurement              1.42E-04               0.5
#   MonteCarlo               4.90E-03              16.7
#   PrintRestart             1.81E-06               0.0
#   SpinCorr                 2.43E-04               0.8
#  -------------------------------------------------------------
#  Total wall time           2.94E-02      Sampled percent  51.1
#  --------------MAIN PROGRAM PHASES TIME REPORT----------------
#  CATEGORY                   EXECUTION TIME    TOTAL CPU TIME
#   Time for initialization :           0.02              0.28
#   Time for initial phase  :           0.00              0.00
#   Time for meas. phase    :           0.01              0.19
#   Time for cleanup        :           0.00              0.00
#  -------------------------------------------------------------
#   Time total              :           0.04              0.47
#   Time for one meas. iter :           0.01              0.19
#  -------------------MEMORY CONSUMPTION REPORT-----------------------
#  5 allocations and 5 deallocations, remaining memory(B):0
#  Memory occupation peak: 0 kB
#  For the array: "indxb_avrg" in routine "averages_allocations"
#  -----------------END MEMORY CONSUMPTION REPORT---------------------
#  --------------------------------------------------------------
#              __  __          ___   _______    ____  ___
#             / / / /__  ___  / _ | / __/ _ \  / __/ / _ \
#            / /_/ / _ \/ _ \/ __ |_\ \/ // / / _ \_/ // /
#            \____/ .__/ .__/_/ |_/___/____/  \___(_)___/
#                /_/  /_/
#  --------------------------------------------------------------
#                 https://github.com/UppASD/UppASD
#  --------------------------------------------------------------
#               Division of Materials Theory
#               Department of Physics and Astronomy
#               Uppsala University
#               Sweden
#  ---------------------Production-version-----------------------
#  Git revision: v6.0.2-136-g553a
#  --------------------------------------------------------------
#  RNG: Mersenne-Twister (mtprng)
#  --------------------------------------------------------------
#  Execution Date: 09/12/2025  Execution Time: 22:18:00:084
#  --------------------------------------------------------------
#  Using OpenMP with 16  threads out of 16 possible.
#  --------------------------------------------------------------
#  Read input file using new format
#  done.
#   Set up types of atoms done
#   Set up chemical information of alloy done
#   Set up global coordinates done
#   Set up damping
#   done
#   Set up temperature
#   done
#  Write input data done.
#  Set up Hamiltonian
#   Set up neighbour map for exchange nntype           0 -2147483648
#  done
#   Mount Heisenberg Hamiltonian done
#   Calculate mean-field estimate of Tc:  ** On entry to DGEEV  parameter number  5 had an illegal value
#   Problem in dgeev:  -5
#    -Inf K.
#   Max eigenvalue:********** meV
#  Initialize metatype
#  Initialize magnetic moments
#   Moments from inpsd.dat  done
#  Enter initial phase:  N
#  Enter measurement phase:
#   MP MC   5% done. Mbar:       NaN. U:     NaN.
#   MP MC  10% done. Mbar:       NaN. U:     NaN.
#   MP MC  15% done. Mbar:       NaN. U:     NaN.
#   MP MC  20% done. Mbar:       NaN. U:     NaN.
#   MP MC  25% done. Mbar:       NaN. U:     NaN.
#   MP MC  30% done. Mbar:       NaN. U:     NaN.
#   MP MC  35% done. Mbar:       NaN. U:     NaN.
#   MP MC  40% done. Mbar:       NaN. U:     NaN.
#   MP MC  45% done. Mbar:       NaN. U:     NaN.
#   MP MC  50% done. Mbar:       NaN. U:     NaN.
#   MP MC  55% done. Mbar:       NaN. U:     NaN.
#   MP MC  60% done. Mbar:       NaN. U:     NaN.
#   MP MC  65% done. Mbar:       NaN. U:     NaN.
#   MP MC  70% done. Mbar:       NaN. U:     NaN.
#   MP MC  75% done. Mbar:       NaN. U:     NaN.
#   MP MC  80% done. Mbar:       NaN. U:     NaN.
#   MP MC  85% done. Mbar:       NaN. U:     NaN.
#   MP MC  90% done. Mbar:       NaN. U:     NaN.
#   MP MC  95% done. Mbar:       NaN. U:     NaN.
#   MP MC 100% done. Mbar:       NaN. U:     NaN.
#  Simulation finished
#  ----------------TIME CONSUMPTION REPORT----------------------
#  CATEGORY                 TIME(sec)           PERCENT
#   Startup                  2.67E-03              15.5
#   Initial                  2.37E-06               0.0
#   Measurement              3.47E-03              20.1
#   MonteCarlo               4.58E-03              26.6
#   PrintRestart             1.87E-06               0.0
#   SpinCorr                 9.81E-05               0.6
#  -------------------------------------------------------------
#  Total wall time           1.72E-02      Sampled percent  62.7
#  --------------MAIN PROGRAM PHASES TIME REPORT----------------
#  CATEGORY                   EXECUTION TIME    TOTAL CPU TIME
#   Time for initialization :           0.00              0.04
#   Time for initial phase  :           0.00              0.00
#   Time for meas. phase    :           0.01              0.23
#   Time for cleanup        :           0.00              0.00
#  -------------------------------------------------------------
#   Time total              :           0.02              0.28
#   Time for one meas. iter :           0.01              0.23
#  -------------------MEMORY CONSUMPTION REPORT-----------------------
#  5 allocations and 5 deallocations, remaining memory(B):0
#  Memory occupation peak: 0 kB
#  For the array: "indxb_avrg" in routine "averages_allocations"
#  -----------------END MEMORY CONSUMPTION REPORT---------------------
#  --------------------------------------------------------------
#              __  __          ___   _______    ____  ___
#             / / / /__  ___  / _ | / __/ _ \  / __/ / _ \
#            / /_/ / _ \/ _ \/ __ |_\ \/ // / / _ \_/ // /
#            \____/ .__/ .__/_/ |_/___/____/  \___(_)___/
#                /_/  /_/
#  --------------------------------------------------------------
#                 https://github.com/UppASD/UppASD
#  --------------------------------------------------------------
#               Division of Materials Theory
#               Department of Physics and Astronomy
#               Uppsala University
#               Sweden
#  ---------------------Production-version-----------------------
#  Git revision: v6.0.2-136-g553a
#  --------------------------------------------------------------
#  RNG: Mersenne-Twister (mtprng)
#  --------------------------------------------------------------
#  Execution Date: 09/12/2025  Execution Time: 22:18:00:186
#  --------------------------------------------------------------
#  Using OpenMP with 16  threads out of 16 possible.
#  --------------------------------------------------------------
#  Read input file using new format
#  done.
#   Set up types of atoms done
#   Set up chemical information of alloy done
#   Set up global coordinates done
#   Set up damping
#   done
#   Set up temperature
#   done
#  Write input data done.
#  Set up Hamiltonian
#   Set up neighbour map for exchange nntype           0 -2147483648
#  done
#   Mount Heisenberg Hamiltonian done
#   Calculate mean-field estimate of Tc:  ** On entry to DGEEV  parameter number  5 had an illegal value
#   Problem in dgeev:  -5
#    -Inf K.
#   Max eigenvalue:********** meV
#  Initialize metatype
#  Initialize magnetic moments
#   Moments from inpsd.dat  done
#  Enter initial phase:  N
#  Enter measurement phase:
#   MP MC   5% done. Mbar:       NaN. U:     NaN.
#   MP MC  10% done. Mbar:       NaN. U:     NaN.
#   MP MC  15% done. Mbar:       NaN. U:     NaN.
#   MP MC  20% done. Mbar:       NaN. U:     NaN.
#   MP MC  25% done. Mbar:       NaN. U:     NaN.
#   MP MC  30% done. Mbar:       NaN. U:     NaN.
#   MP MC  35% done. Mbar:       NaN. U:     NaN.
#   MP MC  40% done. Mbar:       NaN. U:     NaN.
#   MP MC  45% done. Mbar:       NaN. U:     NaN.
#   MP MC  50% done. Mbar:       NaN. U:     NaN.
#   MP MC  55% done. Mbar:       NaN. U:     NaN.
#   MP MC  60% done. Mbar:       NaN. U:     NaN.
#   MP MC  65% done. Mbar:       NaN. U:     NaN.
#   MP MC  70% done. Mbar:       NaN. U:     NaN.
#   MP MC  75% done. Mbar:       NaN. U:     NaN.
#   MP MC  80% done. Mbar:       NaN. U:     NaN.
#   MP MC  85% done. Mbar:       NaN. U:     NaN.
#   MP MC  90% done. Mbar:       NaN. U:     NaN.
#   MP MC  95% done. Mbar:       NaN. U:     NaN.
#   MP MC 100% done. Mbar:       NaN. U:     NaN.
#  Simulation finished
#  ----------------TIME CONSUMPTION REPORT----------------------
#  CATEGORY                 TIME(sec)           PERCENT
#   Startup                  2.49E-03              15.6
#   Initial                  2.25E-06               0.0
#   Measurement              3.41E-03              21.3
#   MonteCarlo               1.71E-03              10.7
#   PrintRestart             1.87E-06               0.0
#   SpinCorr                 3.04E-03              19.0
#  -------------------------------------------------------------
#  Total wall time           1.60E-02      Sampled percent  66.6
#  --------------MAIN PROGRAM PHASES TIME REPORT----------------
#  CATEGORY                   EXECUTION TIME    TOTAL CPU TIME
#   Time for initialization :           0.00              0.04
#   Time for initial phase  :           0.00              0.00
#   Time for meas. phase    :           0.02              0.22
#   Time for cleanup        :           0.00              0.00
#  -------------------------------------------------------------
#   Time total              :           0.02              0.26
#   Time for one meas. iter :           0.02              0.22
#  -------------------MEMORY CONSUMPTION REPORT-----------------------
#  5 allocations and 5 deallocations, remaining memory(B):0
#  Memory occupation peak: 0 kB
#  For the array: "indxb_avrg" in routine "averages_allocations"
#  -----------------END MEMORY CONSUMPTION REPORT---------------------
#  --------------------------------------------------------------
#              __  __          ___   _______    ____  ___
#             / / / /__  ___  / _ | / __/ _ \  / __/ / _ \
#            / /_/ / _ \/ _ \/ __ |_\ \/ // / / _ \_/ // /
#            \____/ .__/ .__/_/ |_/___/____/  \___(_)___/
#                /_/  /_/
#  --------------------------------------------------------------
#                 https://github.com/UppASD/UppASD
#  --------------------------------------------------------------
#               Division of Materials Theory
#               Department of Physics and Astronomy
#               Uppsala University
#               Sweden
#  ---------------------Production-version-----------------------
#  Git revision: v6.0.2-136-g553a
#  --------------------------------------------------------------
#  RNG: Mersenne-Twister (mtprng)
#  --------------------------------------------------------------
#  Execution Date: 09/12/2025  Execution Time: 22:18:00:305
#  --------------------------------------------------------------
#  Using OpenMP with 16  threads out of 16 possible.
#  --------------------------------------------------------------
#  Read input file using new format
#  done.
#   Set up types of atoms done
#   Set up chemical information of alloy done
#   Set up global coordinates done
#   Set up damping
#   done
#   Set up temperature
#   done
#  Write input data done.
#  Set up Hamiltonian
#   Set up neighbour map for exchange nntype           0 -2147483648
#  done
#   Mount Heisenberg Hamiltonian done
#   Calculate mean-field estimate of Tc:  ** On entry to DGEEV  parameter number  5 had an illegal value
#   Problem in dgeev:  -5
#    -Inf K.
#   Max eigenvalue:********** meV
#  Initialize metatype
#  Initialize magnetic moments
#   Moments from inpsd.dat  done
#  Enter initial phase:  N
#  Enter measurement phase:
#   MP MC   5% done. Mbar:       NaN. U:     NaN.
#   MP MC  10% done. Mbar:       NaN. U:     NaN.
#   MP MC  15% done. Mbar:       NaN. U:     NaN.
#   MP MC  20% done. Mbar:       NaN. U:     NaN.
#   MP MC  25% done. Mbar:       NaN. U:     NaN.
#   MP MC  30% done. Mbar:       NaN. U:     NaN.
#   MP MC  35% done. Mbar:       NaN. U:     NaN.
#   MP MC  40% done. Mbar:       NaN. U:     NaN.
#   MP MC  45% done. Mbar:       NaN. U:     NaN.
#   MP MC  50% done. Mbar:       NaN. U:     NaN.
#   MP MC  55% done. Mbar:       NaN. U:     NaN.
#   MP MC  60% done. Mbar:       NaN. U:     NaN.
#   MP MC  65% done. Mbar:       NaN. U:     NaN.
#   MP MC  70% done. Mbar:       NaN. U:     NaN.
#   MP MC  75% done. Mbar:       NaN. U:     NaN.
#   MP MC  80% done. Mbar:       NaN. U:     NaN.
#   MP MC  85% done. Mbar:       NaN. U:     NaN.
#   MP MC  90% done. Mbar:       NaN. U:     NaN.
#   MP MC  95% done. Mbar:       NaN. U:     NaN.
#   MP MC 100% done. Mbar:       NaN. U:     NaN.
#  Simulation finished
#  ----------------TIME CONSUMPTION REPORT----------------------
#  CATEGORY                 TIME(sec)           PERCENT
#   Startup                  1.49E-02              34.0
#   Initial                  6.46E-05               0.1
#   Measurement              1.21E-02              27.5
#   MonteCarlo               5.11E-03              11.7
#   PrintRestart             1.88E-06               0.0
#   SpinCorr                 2.30E-04               0.5
#  -------------------------------------------------------------
#  Total wall time           4.39E-02      Sampled percent  73.9
#  --------------MAIN PROGRAM PHASES TIME REPORT----------------
#  CATEGORY                   EXECUTION TIME    TOTAL CPU TIME
#   Time for initialization :           0.02              0.28
#   Time for initial phase  :           0.00              0.00
#   Time for meas. phase    :           0.03              0.42
#   Time for cleanup        :           0.00              0.00
#  -------------------------------------------------------------
#   Time total              :           0.05              0.70
#   Time for one meas. iter :           0.03              0.42
#  -------------------MEMORY CONSUMPTION REPORT-----------------------
#  5 allocations and 5 deallocations, remaining memory(B):0
#  Memory occupation peak: 0 kB
#  For the array: "indxb_avrg" in routine "averages_allocations"
#  -----------------END MEMORY CONSUMPTION REPORT---------------------
#  --------------------------------------------------------------
#              __  __          ___   _______    ____  ___
#             / / / /__  ___  / _ | / __/ _ \  / __/ / _ \
#            / /_/ / _ \/ _ \/ __ |_\ \/ // / / _ \_/ // /
#            \____/ .__/ .__/_/ |_/___/____/  \___(_)___/
#                /_/  /_/
#  --------------------------------------------------------------
#                 https://github.com/UppASD/UppASD
#  --------------------------------------------------------------
#               Division of Materials Theory
#               Department of Physics and Astronomy
#               Uppsala University
#               Sweden
#  ---------------------Production-version-----------------------
#  Git revision: v6.0.2-136-g553a
#  --------------------------------------------------------------
#  RNG: Mersenne-Twister (mtprng)
#  --------------------------------------------------------------
#  Execution Date: 09/12/2025  Execution Time: 22:18:00:453
#  --------------------------------------------------------------
#  Using OpenMP with 16  threads out of 16 possible.
#  --------------------------------------------------------------
#  Read input file using new format
#  done.
#   Set up types of atoms done
#   Set up chemical information of alloy done
#   Set up global coordinates done
#   Set up damping
#   done
#   Set up temperature
#   done
#  Write input data done.
#  Set up Hamiltonian
#   Set up neighbour map for exchange nntype           0 -2147483648
#  done
#   Mount Heisenberg Hamiltonian done
#   Calculate mean-field estimate of Tc:  ** On entry to DGEEV  parameter number  5 had an illegal value
#   Problem in dgeev:  -5
#    -Inf K.
#   Max eigenvalue:********** meV
#  Initialize metatype
#  Initialize magnetic moments
#   Moments from inpsd.dat  done
#  Enter initial phase:  N
#  Enter measurement phase:
#   MP MC   5% done. Mbar:       NaN. U:     NaN.
#   MP MC  10% done. Mbar:       NaN. U:     NaN.
#   MP MC  15% done. Mbar:       NaN. U:     NaN.
#   MP MC  20% done. Mbar:       NaN. U:     NaN.
#   MP MC  25% done. Mbar:       NaN. U:     NaN.
#   MP MC  30% done. Mbar:       NaN. U:     NaN.
#   MP MC  35% done. Mbar:       NaN. U:     NaN.
#   MP MC  40% done. Mbar:       NaN. U:     NaN.
#   MP MC  45% done. Mbar:       NaN. U:     NaN.
#   MP MC  50% done. Mbar:       NaN. U:     NaN.
#   MP MC  55% done. Mbar:       NaN. U:     NaN.
#   MP MC  60% done. Mbar:       NaN. U:     NaN.
#   MP MC  65% done. Mbar:       NaN. U:     NaN.
#   MP MC  70% done. Mbar:       NaN. U:     NaN.
#   MP MC  75% done. Mbar:       NaN. U:     NaN.
#   MP MC  80% done. Mbar:       NaN. U:     NaN.
#   MP MC  85% done. Mbar:       NaN. U:     NaN.
#   MP MC  90% done. Mbar:       NaN. U:     NaN.
#   MP MC  95% done. Mbar:       NaN. U:     NaN.
#   MP MC 100% done. Mbar:       NaN. U:     NaN.
#  Simulation finished
#  ----------------TIME CONSUMPTION REPORT----------------------
#  CATEGORY                 TIME(sec)           PERCENT
#   Startup                  5.35E-03              21.6
#   Initial                  3.75E-07               0.0
#   Measurement              4.03E-03              16.2
#   MonteCarlo               4.11E-03              16.6
#   PrintRestart             1.87E-06               0.0
#   SpinCorr                 9.48E-05               0.4
#  -------------------------------------------------------------
#  Total wall time           2.48E-02      Sampled percent  54.8
#  --------------MAIN PROGRAM PHASES TIME REPORT----------------
#  CATEGORY                   EXECUTION TIME    TOTAL CPU TIME
#   Time for initialization :           0.01              0.16
#   Time for initial phase  :           0.00              0.00
#   Time for meas. phase    :           0.02              0.24
#   Time for cleanup        :           0.00              0.00
#  -------------------------------------------------------------
#   Time total              :           0.03              0.40
#   Time for one meas. iter :           0.02              0.24
#  -------------------MEMORY CONSUMPTION REPORT-----------------------
#  5 allocations and 5 deallocations, remaining memory(B):0
#  Memory occupation peak: 0 kB
#  For the array: "indxb_avrg" in routine "averages_allocations"
#  -----------------END MEMORY CONSUMPTION REPORT---------------------
#  --------------------------------------------------------------
#              __  __          ___   _______    ____  ___
#             / / / /__  ___  / _ | / __/ _ \  / __/ / _ \
#            / /_/ / _ \/ _ \/ __ |_\ \/ // / / _ \_/ // /
#            \____/ .__/ .__/_/ |_/___/____/  \___(_)___/
#                /_/  /_/
#  --------------------------------------------------------------
#                 https://github.com/UppASD/UppASD
#  --------------------------------------------------------------
#               Division of Materials Theory
#               Department of Physics and Astronomy
#               Uppsala University
#               Sweden
#  ---------------------Production-version-----------------------
#  Git revision: v6.0.2-136-g553a
#  --------------------------------------------------------------
#  RNG: Mersenne-Twister (mtprng)
#  --------------------------------------------------------------
#  Execution Date: 09/12/2025  Execution Time: 22:18:00:572
#  --------------------------------------------------------------
#  Using OpenMP with 16  threads out of 16 possible.
#  --------------------------------------------------------------
#  Read input file using new format
#  done.
#   Set up types of atoms done
#   Set up chemical information of alloy done
#   Set up global coordinates done
#   Set up damping
#   done
#   Set up temperature
#   done
#  Write input data done.
#  Set up Hamiltonian
#   Set up neighbour map for exchange nntype           0 -2147483648
#  done
#   Mount Heisenberg Hamiltonian done
#   Calculate mean-field estimate of Tc:  ** On entry to DGEEV  parameter number  5 had an illegal value
#   Problem in dgeev:  -5
#    -Inf K.
#   Max eigenvalue:********** meV
#  Initialize metatype
#  Initialize magnetic moments
#   Moments from inpsd.dat  done
#  Enter initial phase:  N
#  Enter measurement phase:
#   MP MC   5% done. Mbar:       NaN. U:     NaN.
#   MP MC  10% done. Mbar:       NaN. U:     NaN.
#   MP MC  15% done. Mbar:       NaN. U:     NaN.
#   MP MC  20% done. Mbar:       NaN. U:     NaN.
#   MP MC  25% done. Mbar:       NaN. U:     NaN.
#   MP MC  30% done. Mbar:       NaN. U:     NaN.
#   MP MC  35% done. Mbar:       NaN. U:     NaN.
#   MP MC  40% done. Mbar:       NaN. U:     NaN.
#   MP MC  45% done. Mbar:       NaN. U:     NaN.
#   MP MC  50% done. Mbar:       NaN. U:     NaN.
#   MP MC  55% done. Mbar:       NaN. U:     NaN.
#   MP MC  60% done. Mbar:       NaN. U:     NaN.
#   MP MC  65% done. Mbar:       NaN. U:     NaN.
#   MP MC  70% done. Mbar:       NaN. U:     NaN.
#   MP MC  75% done. Mbar:       NaN. U:     NaN.
#   MP MC  80% done. Mbar:       NaN. U:     NaN.
#   MP MC  85% done. Mbar:       NaN. U:     NaN.
#   MP MC  90% done. Mbar:       NaN. U:     NaN.
#   MP MC  95% done. Mbar:       NaN. U:     NaN.
#   MP MC 100% done. Mbar:       NaN. U:     NaN.
#  Simulation finished
#  ----------------TIME CONSUMPTION REPORT----------------------
#  CATEGORY                 TIME(sec)           PERCENT
#   Startup                  2.99E-03              11.3
#   Initial                  2.37E-06               0.0
#   Measurement              1.56E-04               0.6
#   MonteCarlo               4.82E-03              18.2
#   PrintRestart             1.87E-06               0.0
#   SpinCorr                 4.15E-04               1.6
#  -------------------------------------------------------------
#  Total wall time           2.65E-02      Sampled percent  31.6
#  --------------MAIN PROGRAM PHASES TIME REPORT----------------
#  CATEGORY                   EXECUTION TIME    TOTAL CPU TIME
#   Time for initialization :           0.01              0.17
#   Time for initial phase  :           0.00              0.00
#   Time for meas. phase    :           0.02              0.25
#   Time for cleanup        :           0.00              0.00
#  -------------------------------------------------------------
#   Time total              :           0.03              0.42
#   Time for one meas. iter :           0.02              0.25
#  -------------------MEMORY CONSUMPTION REPORT-----------------------
#  5 allocations and 5 deallocations, remaining memory(B):0
#  Memory occupation peak: 0 kB
#  For the array: "indxb_avrg" in routine "averages_allocations"
#  -----------------END MEMORY CONSUMPTION REPORT---------------------
# TemperatureSweepData('CrNiP/temperature_sweep-0')

# %% [markdown]
# On disk, this call will create the following directory and file structure:
#
# ```
# CrNiP/
#     temperature_sweep-0/
#         run-0/
#             jfile
#             posfile
#             inpsd.dat
#             cumulants.CrNiP.out
#             ...
#             mammos_spindynamics_info.{yaml,toml}
#         run-1/
#             ...
#         run-2/
#             ...
#         ...
#         mammos_spindynamics_info.{yaml,toml}
#         M(T)
# ```
#
# There is generally no need to access any files on the system by hand. Instead we can use the data analysis capabilities coming with `mammos_spindynamics`.
#
# ## Analyzing simulation output
#
# First, we create a data object, which we point to the top-level output directory `CrNiP`. The object recursively finds all files in `CrNiP` and provides access to the simulation results from within Python.

# %%
data = uppasd.read("CrNiP")
data
# Out:
# MammosUppasdData('CrNiP')

# %%
data.info()
# Out:
#                     id                        description    time_elapsed  \
# 0  temperature_sweep-0  Anything the user wants to record  0:00:01.362103
#
#                                                   T
# 0  [10, 60, 110, 160, 210, 260, 310, 360, 410, 460]

# %%
uppasd.MammosUppasdData("CrNiP")
# Out:
# MammosUppasdData('CrNiP')

# %% [markdown]
# We only have one set of outputs in this example. We can acces it as follows:

# %%
sweep_data = data[0]
sweep_data
# Out:
# TemperatureSweepData('CrNiP/temperature_sweep-0')

# %%
uppasd.TemperatureSweepData("CrNiP/temperature_sweep-0")
# Out:
# TemperatureSweepData('CrNiP/temperature_sweep-0')

# %%
uppasd.read("CrNiP/temperature_sweep-0")
# Out:
# TemperatureSweepData('CrNiP/temperature_sweep-0')

# %% [markdown]
# The object allows us to access the array-like simulation output and the temperatures:

# %%
sweep_data.T
# Out:
# Entity(ontology_label='ThermodynamicTemperature', value=array([ 10.,  60., 110., 160., 210., 260., 310., 360., 410., 460.]), unit='K')

# %%
sweep_data.Ms
# Out:
# Entity(ontology_label='SpontaneousMagnetization', value=array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]), unit='A / m')

# %% [markdown]
# We can also access the individual runs:

# %%
run_10K = sweep_data.sel(T=10)
run_10K
# Out:
# RunData('CrNiP/temperature_sweep-0/run-0')

# %%
uppasd.RunData("CrNiP/temperature_sweep-0/run-0")
# Out:
# RunData('CrNiP/temperature_sweep-0/run-0')

# %%
uppasd.read("CrNiP/temperature_sweep-0/run-0")
# Out:
# RunData('CrNiP/temperature_sweep-0/run-0')

# %%
run_10K.metadata
# Out:
# {'UppASD_version': 'v6.0.2',
#  'description': '',
#  'index': 0,
#  'mammos_spindynamics_version': '0.2.4',
#  'mode': 'run',
#  'time_elapsed': '0:00:00.126262',
#  'time_end': '2025-12-09T22:17:59+01:00',
#  'time_start': '2025-12-09T22:17:59+01:00'}

# %%
run_10K.parameters
# Out:
# {'T': 10}

# %%
run_10K.Ms
# Out:
# Entity(ontology_label='SpontaneousMagnetization', value=np.float64(nan), unit='A / m')

# %%
run_10K.restart_file
# Out:
# PosixPath('CrNiP/temperature_sweep-0/run-0/restart._UppASD_.out')

# %%
run_10K.describe(
    include_elapsed_time=True,
    include_index=False,
    include_parameters=True,
    include_description=True,
)
# Out:
# {'id': 'run-0', 'description': '', 'time_elapsed': '0:00:00.126262', 'T': 10}

# %% [markdown]
# ## Kuzmin fit
#
# We can now pass the data from the temperature sweep to the Kuzmin function in `mammos_analysis`:

# %%
kuzmin_result = mammos_analysis.kuzmin.kuzmin_properties(Ms=sweep_data.Ms, T=sweep_data.T)

# %% [markdown]
# The kuzmin result object has a method to plot the temperature dependent parameters:

# %%
kuzmin_result.plot()

# %% [markdown]
# We can also compare against our simulated values directly:

# %%
kuzmin_result.Ms.plot()
plt.plot(range(10, 500, 50), sweep_data.Ms.q, "o")

# %% [markdown]
# We could use results from the Kuzmin fit as inputs for a micromagnetic simulation, e.g. to access parameters at 300 Kelvin (for which we did not run a simulation) we can use:

# %%
kuzmin_result.Ms(300)

# %%
kuzmin_result.A(300)
