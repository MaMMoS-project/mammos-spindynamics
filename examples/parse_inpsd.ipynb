# %% [markdown]
# # Parse `inpsd.dat`

# %%
from mammos_spindynamics import uppasd
import mammos_units as u
import fnmatch

# %%
di = uppasd.parse_inpsd_file("my-first-simulation/run-0/inpsd.dat")
di
# Out:
# {'simid': 'bccFe100',
#  'ncell': array([25., 25., 25.]),
#  'BC': ['P', 'P', 'P'],
#  'cell': array([[ 5.05758866, -2.92000017,  0.        ],
#         [ 0.        ,  5.84000034,  0.        ],
#         [ 0.        ,  0.        ,  3.51400021]]),
#  'posfile': 'D',
#  'posfiletype': 'D',
#  'momfile': './momfile',
#  'exchange': './jASD2',
#  'do_ralloy': 0,
#  'Mensemble': 1,
#  'tseed': 4499,
#  'maptype': 3,
#  'SDEalgh': 1,
#  'Initmag': 3,
#  'ip_mode': 'M',
#  'ip_mcanneal': 1,
#  'temp': 10.0,
#  'mcNstep': 700,
#  'damping': 0.1,
#  'timestep': 1e-16,
#  'do_avrg': 'Y',
#  'do_cumu': 'Y',
#  'cumu_step': 50,
#  'cumu_buff': 10,
#  'do_tottraj': 'Y',
#  'tottraj_step': 1000,
#  'plotenergy': 1,
#  'do_sc': 'C',
#  'do_ams': 'Y',
#  'do_magdos': 'Y',
#  'magdos_freq': 200,
#  'magdos_sigma': 30,
#  'qpoints': 'C',
#  'do_stiffness': 'Y',
#  'eta_max': 12,
#  'eta_min': 6,
#  'alat': 1e-10}

# %%
di["cell"]
# Out:
# array([[ 5.05758866, -2.92000017,  0.        ],
#        [ 0.        ,  5.84000034,  0.        ],
#        [ 0.        ,  0.        ,  3.51400021]])
